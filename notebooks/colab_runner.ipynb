# %%
from google.colab import userdata
import os
os.environ["HUGGINGFACE_HUB_TOKEN"] = userdata.get("HUGGINGFACE_HUB_TOKEN")
os.environ["WANDB_API_KEY"] = userdata.get("WANDB_API_KEY")

# %%
# !uv pip uninstall tensorflow tensorflow-intel keras tensorflow-probability
# Out:
# Using Python 3.12.12 environment at: /usr
# ...
# Uninstalled 3 packages in 1.24s
#  - keras==3.10.0
#  - tensorflow==2.19.0
#  - tensorflow-probability==0.25.0

# %%
# !git clone https://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@github.com/constantineserkov/peft-lora-eval
# %cd peft-lora-eval

# !uv pip install -qq -r requirements_colab.txt

# For src/ imports: Install in editable mode (makes src a package)
# !uv pip install -e .

# Verify GPU and paths
# !nvidia-smi

# !pwd
# Out:
# Cloning into 'peft-lora-eval'...
# remote: Enumerating objects: 543, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 543 (delta 75), reused 78 (delta 44), pack-reused 427 (from 1)
# Receiving objects: 100% (543/543), 241.15 KiB | 11.48 MiB/s, done.
# Resolving deltas: 100% (359/359), done.
# /content/peft-lora-eval
# Using Python 3.12.12 environment at: /usr
# Resolved 102 packages in 244ms
# Prepared 1 package in 678ms
# Installed 1 package in 0.96ms
#  + peft-lora-eval==0.1.0 (from file:///content/peft-lora-eval)
# Fri Nov 21 08:22:11 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# Define base path in Drive (create folder if needed)
import os
base_path = '/content/drive/MyDrive/peft-lora-eval/'
os.makedirs(base_path, exist_ok=True)

# Copy project to Drive (includes installed deps state)
# !cp -r /content/peft-lora-eval/* {base_path}
# %cd {base_path}

# Re-verify in Drive (optional: re-install editable for persistence)
# !uv pip install -e .
# !pwd  # Should show Drive path
# !ls   # Confirm files
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/peft-lora-eval
# Using Python 3.12.12 environment at: /usr
# Resolved 102 packages in 253ms
# Prepared 1 package in 875ms
# Uninstalled 1 package in 0.39ms
# Installed 1 package in 1ms
#  - peft-lora-eval==0.1.0 (from file:///content/peft-lora-eval)
#  + peft-lora-eval==0.1.0 (from file:///content/drive/MyDrive/peft-lora-eval)
# /content/drive/MyDrive/peft-lora-eval
# configs  notebooks		  requirements_colab.txt  setup.py
# data	 peft_lora_eval.egg-info  requirements.txt	  src
# docs	 pyproject.toml		  rt.bat		  tests
# LICENSE  README.md		  scripts		  uv.lock

# %%
import sys
import os
# Fallback sys.path
sys.path.insert(0, '.')

# %%
# !python -m scripts.run_evaluate
# !python -m scripts.run_pipeline --run_id colab_smoke_base_eval --methods base --stages eval --data-subset 20
# Out:
# DEBUG    root: NVML initialized in logger
# INFO     src.logger: Device: cuda
# DEBUG    src.logger: Successfully parsed args
# INFO     src.logger: Local run; base_path=./
# DEBUG    src.logger: config_path: configs/base_config.yaml
# DEBUG    src.logger: Parsed args:
# config_path: configs/base_config.yaml
# method: base
# seed: 17
#
# Config_dict:
# {'project_name': 'peft_lora_eval', 'mode': 'test', 'method': 'base', 'model': {'model_name_or_path': 'meta-llama/Llama-3.1-8B-Instruct'}, 'dataset_name': 'yahma/alpaca-cleaned', 'dataloader': {'batch_size': 2}, 'logging': {'log_every': 500, 'checkpoint_steps': 500, 'log_level': 'DEBUG', 'use_wandb': True}, 'use_small_model': None, 'merge': True, 'seed': 17, 'output_path': 'models\\<method>_best', 'data_subset': 100, 'base_path': './'}
# INFO     src.logger: Seed is set to '17'
# DEBUG    asyncio: Using selector: EpollSelector
# ...
